# %%
# !mkdir /root/.kaggle
# !pip install kaggle
api_token = {"username":"yqliu96","key":"34e41c545a50955f1d1a68f816edcc4e"}
import json
import zipfile
import os
with open('/root/.kaggle/kaggle.json', 'w') as file:
    json.dump(api_token, file)
# !kaggle competitions download -c understanding_cloud_organization
if not os.path.exists("/content/competitions/understanding_cloud_organization"):
    os.makedirs("/content/competitions/understanding_cloud_organization")
os.chdir('/content/competitions/understanding_cloud_organization')
for file in os.listdir():
    zip_ref = zipfile.ZipFile(file, 'r')
    zip_ref.extractall()
    zip_ref.close()
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.6/dist-packages (1.5.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.21.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.6.1)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.12.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from kaggle) (2019.11.28)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.28.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.0.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.6/dist-packages (from python-slugify->kaggle) (1.3)
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.6 / client 1.5.4)
# Downloading train_images.zip to /content
# 100% 3.44G/3.44G [00:38<00:00, 76.1MB/s]
# 100% 3.44G/3.44G [00:38<00:00, 96.6MB/s]
# Downloading test_images.zip to /content
# 100% 2.30G/2.30G [00:32<00:00, 103MB/s]
# 100% 2.30G/2.30G [00:32<00:00, 75.2MB/s]
# Downloading train.csv.zip to /content
#  90% 49.0M/54.2M [00:01<00:00, 21.2MB/s]
# 100% 54.2M/54.2M [00:01<00:00, 36.3MB/s]
# Downloading sample_submission.csv to /content
#   0% 0.00/321k [00:00<?, ?B/s]
# 100% 321k/321k [00:00<00:00, 98.5MB/s]

# %%
# !mkdir /root/.kaggle
# !pip install kaggle
api_token = {"username":"yqliu96","key":"34e41c545a50955f1d1a68f816edcc4e"}
import json
import zipfile
import os
with open('/root/.kaggle/kaggle.json', 'w') as file:
    json.dump(api_token, file)
# !kaggle competitions download -c understanding_cloud_organization
if not os.path.exists("/content/competitions/understanding_cloud_organization"):
    os.makedirs("/content/competitions/understanding_cloud_organization")
os.chdir('/content/competitions/understanding_cloud_organization')
for file in os.listdir():
    zip_ref = zipfile.ZipFile(file, 'r')
    zip_ref.extractall()
    zip_ref.close()
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists
# Requirement already satisfied: kaggle in /usr/local/lib/python3.6/dist-packages (1.5.6)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from kaggle) (2019.11.28)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.6.1)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.28.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.21.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.12.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.0.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.6/dist-packages (from python-slugify->kaggle) (1.3)
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.6 / client 1.5.4)
# Downloading train_images.zip to /content/competitions/understanding_cloud_organization
#  99% 3.43G/3.44G [00:22<00:00, 188MB/s]
# 100% 3.44G/3.44G [00:23<00:00, 160MB/s]
# Downloading test_images.zip to /content/competitions/understanding_cloud_organization
# 100% 2.30G/2.30G [00:15<00:00, 152MB/s]
# 100% 2.30G/2.30G [00:15<00:00, 156MB/s]
# Downloading train.csv.zip to /content/competitions/understanding_cloud_organization
#  83% 45.0M/54.2M [00:00<00:00, 117MB/s]
# 100% 54.2M/54.2M [00:00<00:00, 156MB/s]
# Downloading sample_submission.csv to /content/competitions/understanding_cloud_organization
#   0% 0.00/321k [00:00<?, ?B/s]
# 100% 321k/321k [00:00<00:00, 102MB/s]
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# <ipython-input-2-8efffeef3967> in <module>()
#      12 os.chdir('/content/competitions/understanding_cloud_organization')
#      13 for file in os.listdir():
# ---> 14     zip_ref = zipfile.ZipFile(file, 'r')
#      15     zip_ref.extractall()
#      16     zip_ref.close()
#
# /usr/lib/python3.6/zipfile.py in __init__(self, file, mode, compression, allowZip64)
#    1129         try:
#    1130             if mode == 'r':
# -> 1131                 self._RealGetContents()
#    1132             elif mode in ('w', 'x'):
#    1133                 # set the modified flag so central directory gets written
#
# /usr/lib/python3.6/zipfile.py in _RealGetContents(self)
#    1196             raise BadZipFile("File is not a zip file")
#    1197         if not endrec:
# -> 1198             raise BadZipFile("File is not a zip file")
#    1199         if self.debug > 1:
#    1200             print(endrec)
#
# BadZipFile: File is not a zip file

# %%
import pandas as pd
os.listdir()
# Out:
# ['a46d912.jpg',
#  'c809fd3.jpg',
#  '2698804.jpg',
#  '7edddb3.jpg',
#  'a3c5374.jpg',
#  '948c7b0.jpg',
#  'f031300.jpg',
#  '8647901.jpg',
#  'd3e4e08.jpg',
#  'c34e148.jpg',
#  '3f8492c.jpg',
#  'e991c9f.jpg',
#  '5483c9f.jpg',
#  '71c92cb.jpg',
#  'f2074c1.jpg',
#  'fc72839.jpg',
#  '6a350fd.jpg',
#  '0110417.jpg',
#  '0038327.jpg',
#  '89d2032.jpg',
#  '9adfbd1.jpg',
#  '8497199.jpg',
#  '8d02e7c.jpg',
#  'b80325b.jpg',
#  '4423d67.jpg',
#  '78d47b8.jpg',
#  'b5da352.jpg',
#  'da152e4.jpg',
#  'ed5ca46.jpg',
#  'd451599.jpg',
#  '4446e62.jpg',
#  '71bc08d.jpg',
#  '7416165.jpg',
#  '8e50293.jpg',
#  '4041037.jpg',
#  '897f6f5.jpg',
#  'cf7be7a.jpg',
#  '5777799.jpg',
#  'd26e8dd.jpg',
#  '627d9ce.jpg',
#  '2a58736.jpg',
#  '4720c55.jpg',
#  'e279a73.jpg',
#  'a6e610b.jpg',
#  'e6ce4ce.jpg',
#  '4eb8b08.jpg',
#  '64206cd.jpg',
#  'e892a9b.jpg',
#  'd941623.jpg',
#  'ad2be40.jpg',
#  '4b45b8c.jpg',
#  '1526970.jpg',
#  'b5163d4.jpg',
#  'd90b0fd.jpg',
#  '2028ea5.jpg',
#  'ba9b277.jpg',
#  'bc354be.jpg',
#  'd57001e.jpg',
#  '4c66a43.jpg',
#  '616b301.jpg',
#  '6e15f08.jpg',
#  '8d6beb8.jpg',
#  'c5b3435.jpg',
#  '60e3d09.jpg',
#  '7300e97.jpg',
#  'f00ed2c.jpg',
#  '47eaabe.jpg',
#  '587f5de.jpg',
#  'a47c054.jpg',
#  'b937611.jpg',
#  '71bd68a.jpg',
#  'ae0190b.jpg',
#  '8b9304f.jpg',
#  'a67d89f.jpg',
#  '4070e8b.jpg',
#  'a3c6fa2.jpg',
#  'b1cfac2.jpg',
#  'e807558.jpg',
#  '2efeb98.jpg',
#  '6fa4c8f.jpg',
#  '5914c85.jpg',
#  '29670ce.jpg',
#  '1cf9a34.jpg',
#  '06a0a29.jpg',
#  '69c1ff3.jpg',
#  'aa1ba38.jpg',
#  '810c115.jpg',
#  'f0f0869.jpg',
#  'a4d7cc3.jpg',
#  '59a3d14.jpg',
#  'c9fc9e6.jpg',
#  'ebbbcef.jpg',
#  '1fcc5b9.jpg',
#  'a41d0a2.jpg',
#  'bf3d5b2.jpg',
#  'd2a9756.jpg',
#  'dda3d7f.jpg',
#  'ea37dd3.jpg',
#  'd33574c.jpg',
#  '09da438.jpg',
#  'b538b7c.jpg',
#  'b750857.jpg',
#  'cd3d9ad.jpg',
#  'f8b2107.jpg',
#  'cc4969b.jpg',
#  '7ee5766.jpg',
#  '0cdbaa2.jpg',
#  '67cb8db.jpg',
#  'f5d0668.jpg',
#  '1de79af.jpg',
#  '3c63d91.jpg',
#  '3f25385.jpg',
#  '0b333fa.jpg',
#  'd950b6c.jpg',
#  '774f8c1.jpg',
#  'cb11bcb.jpg',
#  '1629900.jpg',
#  'a9e3ba0.jpg',
#  '2aec718.jpg',
#  '89d53e6.jpg',
#  '371ad5f.jpg',
#  '95df7be.jpg',
#  '33e6e6f.jpg',
#  'e8db7b3.jpg',
#  '644009e.jpg',
#  '5b975be.jpg',
#  '81e8637.jpg',
#  '8e48779.jpg',
#  '5393e22.jpg',
#  '99fc17c.jpg',
#  '4892d82.jpg',
#  'c90d053.jpg',
#  '6bca487.jpg',
#  '926ac3e.jpg',
#  '0a2c1c4.jpg',
#  '7d84cbe.jpg',
#  '325af81.jpg',
#  '44398b9.jpg',
#  '6a0a646.jpg',
#  'bd7a8eb.jpg',
#  '567a1ef.jpg',
#  'a68acd9.jpg',
#  'fbaf935.jpg',
#  '6386934.jpg',
#  'a08f0ee.jpg',
#  'e1dd0de.jpg',
#  'facafc9.jpg',
#  '3cb51e8.jpg',
#  'f32c701.jpg',
#  '38590c1.jpg',
#  'bc1451e.jpg',
#  'ab0585d.jpg',
#  '1ecebd0.jpg',
#  'f33bc65.jpg',
#  '1cf95a2.jpg',
#  '245a60c.jpg',
#  '403f8d4.jpg',
#  'd898344.jpg',
#  'fabbf46.jpg',
#  '97205d7.jpg',
#  'b21f6f7.jpg',
#  '2f466bf.jpg',
#  'c0b4b5b.jpg',
#  '6ca625a.jpg',
#  '0f3e55d.jpg',
#  'a3046a2.jpg',
#  '94daf36.jpg',
#  '61b30c0.jpg',
#  '7b3ed05.jpg',
#  '5b2f22c.jpg',
#  'c3220ac.jpg',
#  '157f26e.jpg',
#  'b433646.jpg',
#  'c372799.jpg',
#  'cf041ee.jpg',
#  '1fae495.jpg',
#  'acbbd2c.jpg',
#  'e84550c.jpg',
#  'b78d1f0.jpg',
#  '6f8d355.jpg',
#  'f8a9217.jpg',
#  'b5ac955.jpg',
#  'a4360d2.jpg',
#  '94f4f2c.jpg',
#  '104643f.jpg',
#  '8e0dd0d.jpg',
#  '0b50c86.jpg',
#  '96140c9.jpg',
#  '23c4d63.jpg',
#  'e2c17f1.jpg',
#  '9879c20.jpg',
#  '56162fb.jpg',
#  'bb3a24e.jpg',
#  '4d582e8.jpg',
#  'aefe2c5.jpg',
#  'b555fdb.jpg',
#  '39f993c.jpg',
#  '461375f.jpg',
#  'c8b1b69.jpg',
#  'f56b158.jpg',
#  '2119f7f.jpg',
#  '6a0deb9.jpg',
#  '3c056ce.jpg',
#  '116ffd1.jpg',
#  '7213b98.jpg',
#  'a3490b6.jpg',
#  'fdbbf1f.jpg',
#  '9a7e743.jpg',
#  '81249d7.jpg',
#  '16519c0.jpg',
#  '71c2b5a.jpg',
#  'aef0886.jpg',
#  '20b272d.jpg',
#  '5f87952.jpg',
#  'cc2b582.jpg',
#  '6b49b68.jpg',
#  'e6ad8d3.jpg',
#  '1f063a1.jpg',
#  'b5a9a17.jpg',
#  '4735d01.jpg',
#  '27dbc77.jpg',
#  '9c0203c.jpg',
#  '9b1f636.jpg',
#  'a60ddfe.jpg',
#  '1487eda.jpg',
#  '7647f9e.jpg',
#  '3b9054c.jpg',
#  'c4a67e3.jpg',
#  'be84271.jpg',
#  '86cc5ae.jpg',
#  '5004466.jpg',
#  '5532d4c.jpg',
#  '68b4159.jpg',
#  '604d877.jpg',
#  'e61c41f.jpg',
#  '6fd0182.jpg',
#  '8ed4866.jpg',
#  '888da7b.jpg',
#  '5e11836.jpg',
#  '65af373.jpg',
#  'd0adc6a.jpg',
#  'e68ad57.jpg',
#  'e35bad8.jpg',
#  'cc4b896.jpg',
#  'c7d8eff.jpg',
#  '985cad8.jpg',
#  'fea8078.jpg',
#  '53f6b8e.jpg',
#  'b617b48.jpg',
#  'a2e5e6b.jpg',
#  '523fc38.jpg',
#  'a9f1d5a.jpg',
#  'd0d9d5f.jpg',
#  'ce0a3b4.jpg',
#  '95f37e9.jpg',
#  'a821809.jpg',
#  '97538c1.jpg',
#  '575c4b6.jpg',
#  '61a06b9.jpg',
#  'aa3b55e.jpg',
#  '2f3c5f3.jpg',
#  '774eff5.jpg',
#  '1fe8681.jpg',
#  '43d43a8.jpg',
#  '122f408.jpg',
#  '13fa2aa.jpg',
#  '1af648a.jpg',
#  '8f3855e.jpg',
#  '4a1d59c.jpg',
#  '4f5985f.jpg',
#  '654f3f6.jpg',
#  '79d8da7.jpg',
#  '54bf7b2.jpg',
#  '0da908c.jpg',
#  '12aa93f.jpg',
#  '21c8b7d.jpg',
#  '8b700ce.jpg',
#  '74981c8.jpg',
#  '9acefa5.jpg',
#  '9886cd2.jpg',
#  '7f64fee.jpg',
#  '2472d3f.jpg',
#  'dfcf51a.jpg',
#  '43fa442.jpg',
#  '3c3d094.jpg',
#  'e0cacb5.jpg',
#  '3c82bc3.jpg',
#  'bed03bc.jpg',
#  '50391d0.jpg',
#  'fae9e36.jpg',
#  '12c1e2a.jpg',
#  '136eeeb.jpg',
#  '332cc25.jpg',
#  '32f7b40.jpg',
#  'ea3ce06.jpg',
#  'edc2b3a.jpg',
#  '940cc57.jpg',
#  'aac0a1c.jpg',
#  'ff3ee29.jpg',
#  '54a9a6f.jpg',
#  '65bce9e.jpg',
#  '75a06d3.jpg',
#  'b6b82c4.jpg',
#  'b7da45f.jpg',
#  '5a23f0c.jpg',
#  'bd3b3f6.jpg',
#  '8e4880d.jpg',
#  '91eaf1b.jpg',
#  '18c4d96.jpg',
#  'fda8a78.jpg',
#  'f662c54.jpg',
#  '68e6a87.jpg',
#  'cad4411.jpg',
#  '61e3406.jpg',
#  '9e3346e.jpg',
#  'f83c548.jpg',
#  '13c75bf.jpg',
#  '61e5415.jpg',
#  'b717f32.jpg',
#  'a2f11a3.jpg',
#  '2f00936.jpg',
#  '3aa0db5.jpg',
#  '29c47fa.jpg',
#  'df55e98.jpg',
#  '985a06f.jpg',
#  '002f507.jpg',
#  'f25f1a5.jpg',
#  '1a7926a.jpg',
#  'a5a603f.jpg',
#  '05316ef.jpg',
#  'c2ea229.jpg',
#  'cf48b7f.jpg',
#  '68ff3dd.jpg',
#  '41a45d9.jpg',
#  'b982800.jpg',
#  '9240cf7.jpg',
#  '11c7bad.jpg',
#  'bc34146.jpg',
#  '05bdead.jpg',
#  '5aee7d1.jpg',
#  'c6c2b98.jpg',
#  '900e615.jpg',
#  '9800a22.jpg',
#  'dce7e94.jpg',
#  'cb307e3.jpg',
#  '5216df7.jpg',
#  '3473a5f.jpg',
#  'eddbba6.jpg',
#  '10055ff.jpg',
#  '47d1355.jpg',
#  'd5c5789.jpg',
#  '1741aa3.jpg',
#  '719307c.jpg',
#  '00db8b3.jpg',
#  '5d97e6f.jpg',
#  '4d94381.jpg',
#  '01d8c02.jpg',
#  'c98b396.jpg',
#  '3827144.jpg',
#  'be6644d.jpg',
#  'c0c79f2.jpg',
#  'f774da8.jpg',
#  '5013206.jpg',
#  '96dd887.jpg',
#  '7e64de6.jpg',
#  '33c5c29.jpg',
#  '724f9eb.jpg',
#  '494e6be.jpg',
#  '694177c.jpg',
#  '2180ee4.jpg',
#  'a4c0e0d.jpg',
#  '92e529e.jpg',
#  '65696a0.jpg',
#  'cb29d72.jpg',
#  'e1e7132.jpg',
#  '0bb3efe.jpg',
#  '7cc3ed5.jpg',
#  '86af61e.jpg',
#  '0b7c7af.jpg',
#  '0332698.jpg',
#  '2e27585.jpg',
#  '9f03f21.jpg',
#  '733f4f2.jpg',
#  '8fa693e.jpg',
#  'fcdd475.jpg',
#  'f6c8502.jpg',
#  '18dfbf9.jpg',
#  '87e77a4.jpg',
#  '4792a7e.jpg',
#  'cfc59f9.jpg',
#  'dc2736b.jpg',
#  '09ec64e.jpg',
#  'cde5314.jpg',
#  '3b26a40.jpg',
#  'a3005c2.jpg',
#  '37ad2e3.jpg',
#  '4d91963.jpg',
#  'b7b9729.jpg',
#  'da942b1.jpg',
#  '9b0e162.jpg',
#  '76ff6b6.jpg',
#  'bed2c8b.jpg',
#  '4b990b9.jpg',
#  '8d87c7b.jpg',
#  'da58c16.jpg',
#  'd61cab9.jpg',
#  '76fcbee.jpg',
#  '9beba1d.jpg',
#  '33c8efa.jpg',
#  '23253e3.jpg',
#  'e5cef1e.jpg',
#  '7de2792.jpg',
#  '447b21d.jpg',
#  '6aad364.jpg',
#  '4d725c7.jpg',
#  'e8884df.jpg',
#  'eb4f28e.jpg',
#  'cb37b24.jpg',
#  'a2cfc81.jpg',
#  'a0e155a.jpg',
#  '5e8d6a7.jpg',
#  '5bcd444.jpg',
#  'b1f566f.jpg',
#  '1101c12.jpg',
#  '5502122.jpg',
#  '48c2591.jpg',
#  '0bb7fb2.jpg',
#  '06dd7d4.jpg',
#  '031bdd3.jpg',
#  'bb5df48.jpg',
#  '87edc8b.jpg',
#  '679ee38.jpg',
#  '0e95a79.jpg',
#  '6d56f65.jpg',
#  'a2989c2.jpg',
#  'f66db64.jpg',
#  '967a93d.jpg',
#  '1c26c1b.jpg',
#  'a7cb137.jpg',
#  '8c5937e.jpg',
#  'a87bf53.jpg',
#  'f456d2d.jpg',
#  'f595d0b.jpg',
#  '82d44f8.jpg',
#  '2233581.jpg',
#  '5dceaf0.jpg',
#  '2a282ca.jpg',
#  '2f24572.jpg',
#  'cf2e7ef.jpg',
#  '3cf6440.jpg',
#  '303179e.jpg',
#  '141ae33.jpg',
#  '6b9e2ad.jpg',
#  '4d5ce80.jpg',
#  '5960170.jpg',
#  '01e507a.jpg',
#  '6d8012f.jpg',
#  'ab491cf.jpg',
#  '1689ce5.jpg',
#  'fd8f106.jpg',
#  'f885216.jpg',
#  '3548914.jpg',
#  '7e696d3.jpg',
#  '5e75ed1.jpg',
#  'be003ba.jpg',
#  '1c876bc.jpg',
#  '8fd65c2.jpg',
#  '31f6539.jpg',
#  '74c3d8b.jpg',
#  '6c76a90.jpg',
#  'cc8f0f8.jpg',
#  '45da8c8.jpg',
#  '10bc00e.jpg',
#  '1846f70.jpg',
#  '578167f.jpg',
#  'e448df8.jpg',
#  '8445a94.jpg',
#  'fdfd67d.jpg',
#  '9849ad1.jpg',
#  '64fa875.jpg',
#  '41219ea.jpg',
#  '89f5ba7.jpg',
#  '3829503.jpg',
#  '278fd1d.jpg',
#  '27eec40.jpg',
#  'c00941c.jpg',
#  '94bd2ab.jpg',
#  'e2b0796.jpg',
#  '134eadc.jpg',
#  '4f0aa44.jpg',
#  'b6d499b.jpg',
#  '406ac2a.jpg',
#  '46291c7.jpg',
#  '068180b.jpg',
#  '49c1387.jpg',
#  '0403d7b.jpg',
#  'e77577b.jpg',
#  'f2659f1.jpg',
#  'db5ddf6.jpg',
#  'd9ce162.jpg',
#  'b8f8fc0.jpg',
#  'bd7d0b2.jpg',
#  '300897a.jpg',
#  '714f904.jpg',
#  '12a67ac.jpg',
#  '08f5db0.jpg',
#  '78cc8cc.jpg',
#  'f9ec8d3.jpg',
#  'c593f41.jpg',
#  '5d61821.jpg',
#  '558561e.jpg',
#  'ba625b6.jpg',
#  '5410159.jpg',
#  'f62ec2b.jpg',
#  '53e859e.jpg',
#  'be28372.jpg',
#  'cd7e313.jpg',
#  '375c1f9.jpg',
#  'b2aed33.jpg',
#  '3bf9dd0.jpg',
#  '48a3a17.jpg',
#  '5aac8c5.jpg',
#  'fbe8f08.jpg',
#  '7fbb019.jpg',
#  '2bff8a9.jpg',
#  'c5441e8.jpg',
#  'ebe5621.jpg',
#  'ffc72da.jpg',
#  '4e53795.jpg',
#  '1b049ee.jpg',
#  '61fb592.jpg',
#  'f86dc6d.jpg',
#  'd9297ef.jpg',
#  '7622670.jpg',
#  '809dd74.jpg',
#  '9dfbb5e.jpg',
#  'a2e3648.jpg',
#  '8bc82b5.jpg',
#  'ebc777c.jpg',
#  '33f0f81.jpg',
#  '11e6710.jpg',
#  '5465168.jpg',
#  '1c82524.jpg',
#  'ac1c76e.jpg',
#  '2905b3e.jpg',
#  '84d689d.jpg',
#  '4f00f60.jpg',
#  '5e58d60.jpg',
#  'c147632.jpg',
#  '3c54721.jpg',
#  '51cae9e.jpg',
#  '1880e90.jpg',
#  '90e2586.jpg',
#  '9f85a53.jpg',
#  'f7f38ae.jpg',
#  'b810769.jpg',
#  '7fa5c99.jpg',
#  '4366ba6.jpg',
#  '6f8ec65.jpg',
#  '3656741.jpg',
#  '13a4a11.jpg',
#  '781facd.jpg',
#  '0a16aa9.jpg',
#  '301d2a2.jpg',
#  '584a78f.jpg',
#  '264639f.jpg',
#  'a430675.jpg',
#  '006440a.jpg',
#  '80cc1ef.jpg',
#  '89f4a64.jpg',
#  '271beba.jpg',
#  '5c1da1c.jpg',
#  '9fb4018.jpg',
#  'aa16dd4.jpg',
#  '5569260.jpg',
#  '9422157.jpg',
#  '751f46e.jpg',
#  'ceec4b3.jpg',
#  'e631af8.jpg',
#  '42bd562.jpg',
#  '4a38465.jpg',
#  '35f8718.jpg',
#  '11c9b3c.jpg',
#  '3d884ac.jpg',
#  '4414ba6.jpg',
#  '1e38e20.jpg',
#  'e58017a.jpg',
#  '34c9915.jpg',
#  '5b5abe5.jpg',
#  '88a7a09.jpg',
#  'a18ad3f.jpg',
#  'bd8338c.jpg',
#  'c5301a3.jpg',
#  'afcea2f.jpg',
#  '18cbf0e.jpg',
#  'fa827f5.jpg',
#  '816c3b7.jpg',
#  'f8b6657.jpg',
#  'e0d4168.jpg',
#  '4e1c4a2.jpg',
#  'c7e0964.jpg',
#  'cf543b6.jpg',
#  'e689873.jpg',
#  '58ec7c4.jpg',
#  'da6421b.jpg',
#  'edc29fa.jpg',
#  '868edaa.jpg',
#  '614ede3.jpg',
#  'b8f492e.jpg',
#  'af75f46.jpg',
#  '2aa962d.jpg',
#  'fa52a38.jpg',
#  '6b916a3.jpg',
#  '99916ed.jpg',
#  'a746fbe.jpg',
#  '597ee55.jpg',
#  '0e8f773.jpg',
#  '3b6c490.jpg',
#  'e23c8be.jpg',
#  '053769f.jpg',
#  'f22bf2a.jpg',
#  'a0edf26.jpg',
#  'd6dd4f6.jpg',
#  '375d9e1.jpg',
#  '25fa788.jpg',
#  '8fb6049.jpg',
#  '8516322.jpg',
#  '07927a4.jpg',
#  '667e38f.jpg',
#  '11129df.jpg',
#  '195efaf.jpg',
#  'b5c7712.jpg',
#  '6a48047.jpg',
#  'e494c04.jpg',
#  '0a683c2.jpg',
#  '838a75c.jpg',
#  '87f2176.jpg',
#  'bf14af9.jpg',
#  'b0fdffe.jpg',
#  '71c582a.jpg',
#  '17a96ba.jpg',
#  'fff3c5c.jpg',
#  '716861e.jpg',
#  '80ff5dd.jpg',
#  '628350d.jpg',
#  'acfc0d7.jpg',
#  '6970e13.jpg',
#  'b048858.jpg',
#  '80a46a5.jpg',
#  'ce8df6b.jpg',
#  '1709dc3.jpg',
#  '558d114.jpg',
#  '1cc856f.jpg',
#  '6142c4a.jpg',
#  '3d6011a.jpg',
#  'bf4ddbb.jpg',
#  '72c71c9.jpg',
#  '703182c.jpg',
#  'c9ff807.jpg',
#  '9c3b897.jpg',
#  '74514d6.jpg',
#  '966042d.jpg',
#  '5e51c1b.jpg',
#  '3aa8cfd.jpg',
#  '38a978a.jpg',
#  'e907044.jpg',
#  'bc54f81.jpg',
#  '9cb6ccd.jpg',
#  '393a273.jpg',
#  '4334a4e.jpg',
#  '6674711.jpg',
#  '7aac83e.jpg',
#  '9938bc7.jpg',
#  'd55da1a.jpg',
#  'bdc4bed.jpg',
#  '4ae5cc6.jpg',
#  '66e5939.jpg',
#  '3de6c86.jpg',
#  '57a2f56.jpg',
#  '1b8f086.jpg',
#  '03c28bc.jpg',
#  'c24ed11.jpg',
#  '082f45e.jpg',
#  '3489802.jpg',
#  '1eae534.jpg',
#  'cc4cdb9.jpg',
#  '0b14033.jpg',
#  'd627b83.jpg',
#  '62547ab.jpg',
#  'e862227.jpg',
#  '9777173.jpg',
#  'ac365cb.jpg',
#  '2ae682e.jpg',
#  'c3f53b4.jpg',
#  'd9f4aa8.jpg',
#  '1f456aa.jpg',
#  '2373f56.jpg',
#  'e7c1955.jpg',
#  'e307838.jpg',
#  '390813f.jpg',
#  'bfcd369.jpg',
#  'a87972a.jpg',
#  '20d84e4.jpg',
#  'b09274d.jpg',
#  'e08c9da.jpg',
#  'fa7bc8a.jpg',
#  'b81115b.jpg',
#  '75cfde2.jpg',
#  'e4244ab.jpg',
#  '78d0604.jpg',
#  'a81420a.jpg',
#  '4e6c376.jpg',
#  'a80d6a8.jpg',
#  'ea91bb4.jpg',
#  '7cdd13b.jpg',
#  '781cfaa.jpg',
#  '2dd476c.jpg',
#  '423f808.jpg',
#  '79dbfc2.jpg',
#  'c959bdf.jpg',
#  '877f1a7.jpg',
#  '3e4c725.jpg',
#  '41ee202.jpg',
#  '17bd8a8.jpg',
#  '53ad624.jpg',
#  'f8822c1.jpg',
#  '8b96a9a.jpg',
#  '714b8e1.jpg',
#  'd0da6f1.jpg',
#  '52b8e4f.jpg',
#  'deef0bf.jpg',
#  '6cf023d.jpg',
#  'f764011.jpg',
#  '99d1df6.jpg',
#  'e7d9f8f.jpg',
#  'c642470.jpg',
#  '39906d8.jpg',
#  '713a074.jpg',
#  '5581ac9.jpg',
#  '87ffa0b.jpg',
#  'd1d6a4c.jpg',
#  'c27cfb7.jpg',
#  '5b56dd7.jpg',
#  'c078421.jpg',
#  'd89c536.jpg',
#  '31f1ef5.jpg',
#  '9bb74ed.jpg',
#  '0bdbf44.jpg',
#  'b79eb8b.jpg',
#  '0c61125.jpg',
#  '7acbb6b.jpg',
#  '5964a7a.jpg',
#  '90fa399.jpg',
#  '032518b.jpg',
#  '1868603.jpg',
#  'dd9d67a.jpg',
#  '7b97e8c.jpg',
#  'a3f3e5d.jpg',
#  '11c4de6.jpg',
#  '3cca782.jpg',
#  'a495eb0.jpg',
#  'f7c35e3.jpg',
#  'c3d1c31.jpg',
#  '3b6ffc4.jpg',
#  'c878c6f.jpg',
#  'e48e60b.jpg',
#  '24511de.jpg',
#  '428889a.jpg',
#  '4684ee5.jpg',
#  '266e9d7.jpg',
#  'f28c0b6.jpg',
#  'e8db1ff.jpg',
#  '68729b6.jpg',
#  '25929c2.jpg',
#  '36f2683.jpg',
#  '3ea96a0.jpg',
#  '904778d.jpg',
#  'a359be0.jpg',
#  'test_images.zip',
#  'a7ff5ab.jpg',
#  '6e30fd6.jpg',
#  '116b9e0.jpg',
#  '7c1bfc2.jpg',
#  'c17d6a1.jpg',
#  '1a374d4.jpg',
#  'd306f03.jpg',
#  'b09441b.jpg',
#  'eeace91.jpg',
#  '4b4ee08.jpg',
#  '700e9bc.jpg',
#  '1c5b498.jpg',
#  '4d93295.jpg',
#  '88b9a34.jpg',
#  'afe6444.jpg',
#  'c5fb7cc.jpg',
#  '16fe320.jpg',
#  'edda79c.jpg',
#  'fae43cb.jpg',
#  '7ee2391.jpg',
#  'a00df1e.jpg',
#  'a75548c.jpg',
#  'fa84413.jpg',
#  'd83724a.jpg',
#  'c405535.jpg',
#  '668d02a.jpg',
#  'a3b6049.jpg',
#  '58a57dc.jpg',
#  '0f2b2b7.jpg',
#  '7bfd351.jpg',
#  '7e7edd3.jpg',
#  '07e9514.jpg',
#  'a1d1153.jpg',
#  '7b669a8.jpg',
#  '8ff3d4a.jpg',
#  'bb03917.jpg',
#  '586d3f4.jpg',
#  '0bcdc0b.jpg',
#  '5a54613.jpg',
#  '4a8f4b7.jpg',
#  '9e0716b.jpg',
#  '70173e3.jpg',
#  '2951d77.jpg',
#  'e75cb35.jpg',
#  '06bf6b6.jpg',
#  '52f87bd.jpg',
#  '4c87181.jpg',
#  '0cd6b74.jpg',
#  '177fe57.jpg',
#  'b63d94b.jpg',
#  'a2388c2.jpg',
#  '8531ae0.jpg',
#  '5f5df1e.jpg',
#  '64dee2a.jpg',
#  '60853e7.jpg',
#  '97dfbf7.jpg',
#  'caa62f1.jpg',
#  '3196742.jpg',
#  'd3f716d.jpg',
#  '814335f.jpg',
#  'ec57872.jpg',
#  '15aa9c8.jpg',
#  'c8c3656.jpg',
#  'a02d3bf.jpg',
#  'ef4745d.jpg',
#  '5a3594d.jpg',
#  '818ff1d.jpg',
#  'df1957e.jpg',
#  '034e0ea.jpg',
#  '97d6429.jpg',
#  '576f84b.jpg',
#  '8d9f6f5.jpg',
#  '11bc3f1.jpg',
#  'fc22d2d.jpg',
#  'fc82e25.jpg',
#  '3f08c89.jpg',
#  'b18959d.jpg',
#  '173cd32.jpg',
#  'd3d9be8.jpg',
#  '31029e8.jpg',
#  'e810552.jpg',
#  '60d4397.jpg',
#  'c281290.jpg',
#  'f5ab036.jpg',
#  '637ac24.jpg',
#  '2246e8a.jpg',
#  'f6c745c.jpg',
#  'fbc3cf2.jpg',
#  '244c0f9.jpg',
#  'a6734e2.jpg',
#  '8e86e36.jpg',
#  'eb2e883.jpg',
#  '1b12bd5.jpg',
#  'bc591af.jpg',
#  'd7aa42d.jpg',
#  '2b8f02a.jpg',
#  '69b497a.jpg',
#  'd129060.jpg',
#  '7522c8d.jpg',
#  '9931011.jpg',
#  '9bfeda9.jpg',
#  '3219142.jpg',
#  '84c98d0.jpg',
#  'ead95e7.jpg',
#  '4943a64.jpg',
#  'e767ea3.jpg',
#  '4010009.jpg',
#  '73fc053.jpg',
#  'f2be4dd.jpg',
#  '0feca26.jpg',
#  'e60503c.jpg',
#  '0cb4cfe.jpg',
#  'c7bc71e.jpg',
#  '103955f.jpg',
#  '2ae74d4.jpg',
#  '4676ff1.jpg',
#  'e858f12.jpg',
#  '6082b3b.jpg',
#  '4204b96.jpg',
#  '1d743be.jpg',
#  '9855133.jpg',
#  'f66709c.jpg',
#  'ff2a5ae.jpg',
#  '7f97924.jpg',
#  'ee65d2b.jpg',
#  'a566d97.jpg',
#  'c89b983.jpg',
#  '34d3a6e.jpg',
#  '6fc16bb.jpg',
#  '4a73cae.jpg',
#  '459e342.jpg',
#  '1dc5547.jpg',
#  '40b63a2.jpg',
#  'd2e6ea5.jpg',
#  '3d022da.jpg',
#  'f1842af.jpg',
#  'e751dba.jpg',
#  '3bfb277.jpg',
#  'b587dbd.jpg',
#  '4266a44.jpg',
#  '9c15ed5.jpg',
#  '02a1a4f.jpg',
#  '97a9dc5.jpg',
#  '65b75f4.jpg',
#  '1dbd0c9.jpg',
#  '969f34b.jpg',
#  '3d9dd27.jpg',
#  '52df6cd.jpg',
#  'b2646b4.jpg',
#  'c3ea544.jpg',
#  '1c71ee8.jpg',
#  'bd1b55b.jpg',
#  '8e4af27.jpg',
#  '6e1827b.jpg',
#  'b5cb728.jpg',
#  'fb0ca83.jpg',
#  '090c62f.jpg',
#  '5d4fe0d.jpg',
#  '23f67c1.jpg',
#  'c96a28f.jpg',
#  '8ab9255.jpg',
#  'ea94539.jpg',
#  '809c433.jpg',
#  'c7e25be.jpg',
#  '969196c.jpg',
#  'c40858a.jpg',
#  '2465c38.jpg',
#  'ce973db.jpg',
#  '15091cd.jpg',
#  'b0b4d05.jpg',
#  '0479385.jpg',
#  'ebb2eb5.jpg',
#  '60a4c6a.jpg',
#  '97b3bfb.jpg',
#  '0818dfa.jpg',
#  '9b9414c.jpg',
#  'a70659c.jpg',
#  'e9d3fe6.jpg',
#  'd5d5a40.jpg',
#  'd45008a.jpg',
#  'dc0bf20.jpg',
#  'ad31ca0.jpg',
#  '82d4341.jpg',
#  '6125990.jpg',
#  'a4a6824.jpg',
#  '1baef44.jpg',
#  'fee151c.jpg',
#  '54fd1fc.jpg',
#  '0e02769.jpg',
#  'd88298e.jpg',
#  '8de73e4.jpg',
#  '84e3216.jpg',
#  'ac778b9.jpg',
#  '464bbbc.jpg',
#  '66adf87.jpg',
#  '205719f.jpg',
#  '27d35a5.jpg',
#  'a5206cd.jpg',
#  '692de93.jpg',
#  '211c816.jpg',
#  '054dfc1.jpg',
#  'f034b38.jpg',
#  '6485bf7.jpg',
#  '0734335.jpg',
#  '5954c38.jpg',
#  'b8703a2.jpg',
#  '03ec713.jpg',
#  'c489c44.jpg',
#  '71234c4.jpg',
#  '08ea174.jpg',
#  '28a75c6.jpg',
#  '7d59ab4.jpg',
#  'ba5faf6.jpg',
#  '65a8319.jpg',
#  '0b3a6a2.jpg',
#  'd7fd35b.jpg',
#  'f231e36.jpg',
#  'ee2e015.jpg',
#  'e029c67.jpg',
#  'f38ef1d.jpg',
#  'f053dec.jpg',
#  ...]

# %%
path = '/content/competitions/understanding_cloud_organization'
sub = pd.read_csv(f'{path}/sample_submission.csv')
# read csv
train_df = pd.read_csv(f'{path}/train.csv.zip')
#train_df = train_df.dropna()
train_df.head()
sub.head()
# Out:
#           Image_Label                                      EncodedPixels
# 0    0011165.jpg_Fish  264918 937 266318 937 267718 937 269118 937 27...
# 1  0011165.jpg_Flower  1355565 1002 1356965 1002 1358365 1002 1359765...
# 2  0011165.jpg_Gravel                                                NaN
# 3   0011165.jpg_Sugar                                                NaN
# 4    002be4f.jpg_Fish  233813 878 235213 878 236613 878 238010 881 23...

# %%
2
# Out:
# 2

# %%
import numpy as np

# %%
mask_count_df = train_df.groupby('ImageId').agg(np.sum).reset_index()
mask_count_df.sort_values('hasMask', ascending=False, inplace=True)
print(mask_count_df.shape)
mask_count_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-b587265b1a58> in <module>()
# ----> 1 mask_count_df = train_df.groupby('ImageId').agg(np.sum).reset_index()
#       2 mask_count_df.sort_values('hasMask', ascending=False, inplace=True)
#       3 print(mask_count_df.shape)
#       4 mask_count_df.head()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7892             squeeze=squeeze,
#    7893             observed=observed,
# -> 7894             **kwargs
#    7895         )
#    7896
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/groupby/groupby.py in groupby(obj, by, **kwds)
#    2520         raise TypeError("invalid type: {}".format(obj))
#    2521
# -> 2522     return klass(obj, by, **kwds)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     389                 sort=sort,
#     390                 observed=observed,
# --> 391                 mutated=self.mutated,
#     392             )
#     393
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/groupby/grouper.py in _get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#     619                 in_axis, name, level, gpr = False, None, gpr, None
#     620             else:
# --> 621                 raise KeyError(gpr)
#     622         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     623             # Add key to exclusions
#
# KeyError: 'ImageId'

# %%
#sub_df = pd.read_csv('../input/sample_submission.csv')
sub['ImageId'] = sub['Image_Label'].apply(lambda x: x.split('_')[0])
test_imgs = pd.DataFrame(sub['ImageId'].unique(), columns=['ImageId'])

# %%
def np_resize(img, input_shape):
    """
    Reshape a numpy array, which is input_shape=(height, width), 
    as opposed to input_shape=(width, height) for cv2
    """
    height, width = input_shape
    return cv2.resize(img, (width, height))
    
def mask2rle(img):
    '''
    img: numpy array, 1 - mask, 0 - background
    Returns run length as string formated
    '''
    pixels= img.T.flatten()
    pixels = np.concatenate([[0], pixels, [0]])
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
    runs[1::2] -= runs[::2]
    return ' '.join(str(x) for x in runs)

def rle2mask(rle, input_shape):
    width, height = input_shape[:2]
    
    mask= np.zeros( width*height ).astype(np.uint8)
    
    array = np.asarray([int(x) for x in rle.split()])
    starts = array[0::2]
    lengths = array[1::2]

    current_position = 0
    for index, start in enumerate(starts):
        mask[int(start):int(start+lengths[index])] = 1
        current_position += lengths[index]
        
    return mask.reshape(height, width).T

def build_masks(rles, input_shape, reshape=None):
    depth = len(rles)
    if reshape is None:
        masks = np.zeros((*input_shape, depth))
    else:
        masks = np.zeros((*reshape, depth))
    
    for i, rle in enumerate(rles):
        if type(rle) is str:
            if reshape is None:
                masks[:, :, i] = rle2mask(rle, input_shape)
            else:
                mask = rle2mask(rle, input_shape)
                reshaped_mask = np_resize(mask, reshape)
                masks[:, :, i] = reshaped_mask
    
    return masks

def build_rles(masks, reshape=None):
    width, height, depth = masks.shape
    
    rles = []
    
    for i in range(depth):
        mask = masks[:, :, i]
        
        if reshape:
            mask = mask.astype(np.float32)
            mask = np_resize(mask, reshape).astype(np.int64)
        
        rle = mask2rle(mask)
        rles.append(rle)
        
    return rles

# %%
# !pip install segmentation-models --quiet
import os
import json

import albumentations as albu
import cv2
import keras
from keras import backend as K
from keras.models import Model
from keras.layers import Input
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.losses import binary_crossentropy
from keras.optimizers import Adam, Nadam
from keras.callbacks import Callback, ModelCheckpoint
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tqdm import tqdm
import tensorflow as tf
from sklearn.model_selection import train_test_split
import segmentation_models as sm

# %%
keras_version = tf.keras.__version__
keras_version
# Out:
# '2.2.4-tf'

# %%
class RAdam(keras.optimizers.Optimizer):
    """RAdam optimizer.
    # Arguments
        lr: float >= 0. Learning rate.
        beta_1: float, 0 < beta < 1. Generally close to 1.
        beta_2: float, 0 < beta < 1. Generally close to 1.
        epsilon: float >= 0. Fuzz factor. If `None`, defaults to `K.epsilon()`.
        decay: float >= 0. Learning rate decay over each update.
        weight_decay: float >= 0. Weight decay for each param.
        amsgrad: boolean. Whether to apply the AMSGrad variant of this
            algorithm from the paper "On the Convergence of Adam and
            Beyond".
        total_steps: int >= 0. Total number of training steps. Enable warmup by setting a positive value.
        warmup_proportion: 0 < warmup_proportion < 1. The proportion of increasing steps.
        min_lr: float >= 0. Minimum learning rate after warmup.
    # References
        - [Adam - A Method for Stochastic Optimization](https://arxiv.org/abs/1412.6980v8)
        - [On the Convergence of Adam and Beyond](https://openreview.net/forum?id=ryQu7f-RZ)
        - [On The Variance Of The Adaptive Learning Rate And Beyond](https://arxiv.org/pdf/1908.03265v1.pdf)
    """

    def __init__(self, lr=0.001, beta_1=0.9, beta_2=0.999,
                 epsilon=None, decay=0., weight_decay=0., amsgrad=False,
                 total_steps=0, warmup_proportion=0.1, min_lr=0., **kwargs):
        super(RAdam, self).__init__(**kwargs)
        with K.name_scope(self.__class__.__name__):
            self.iterations = K.variable(0, dtype='int64', name='iterations')
            self.lr = K.variable(lr, name='lr')
            self.beta_1 = K.variable(beta_1, name='beta_1')
            self.beta_2 = K.variable(beta_2, name='beta_2')
            self.decay = K.variable(decay, name='decay')
            self.weight_decay = K.variable(weight_decay, name='weight_decay')
            self.total_steps = K.variable(total_steps, name='total_steps')
            self.warmup_proportion = K.variable(warmup_proportion, name='warmup_proportion')
            self.min_lr = K.variable(min_lr, name='min_lr')
        if epsilon is None:
            epsilon = K.epsilon()
        self.epsilon = epsilon
        self.initial_decay = decay
        self.initial_weight_decay = weight_decay
        self.initial_total_steps = total_steps
        self.amsgrad = amsgrad

    def get_updates(self, loss, params):
        grads = self.get_gradients(loss, params)
        self.updates = [K.update_add(self.iterations, 1)]

        lr = self.lr

        if self.initial_decay > 0:
            lr = lr * (1. / (1. + self.decay * K.cast(self.iterations, K.dtype(self.decay))))

        t = K.cast(self.iterations, K.floatx()) + 1

        if self.initial_total_steps > 0:
            warmup_steps = self.total_steps * self.warmup_proportion
            lr = K.switch(
                t <= warmup_steps,
                lr * (t / warmup_steps),
                self.min_lr + (lr - self.min_lr) * (1.0 - K.minimum(t, self.total_steps) / self.total_steps),
            )

        ms = [K.zeros(K.int_shape(p), dtype=K.dtype(p), name='m_' + str(i)) for (i, p) in enumerate(params)]
        vs = [K.zeros(K.int_shape(p), dtype=K.dtype(p), name='v_' + str(i)) for (i, p) in enumerate(params)]

        if self.amsgrad:
            vhats = [K.zeros(K.int_shape(p), dtype=K.dtype(p), name='vhat_' + str(i)) for (i, p) in enumerate(params)]
        else:
            vhats = [K.zeros(1, name='vhat_' + str(i)) for i in range(len(params))]

        self.weights = [self.iterations] + ms + vs + vhats

        beta_1_t = K.pow(self.beta_1, t)
        beta_2_t = K.pow(self.beta_2, t)

        sma_inf = 2.0 / (1.0 - self.beta_2) - 1.0
        sma_t = sma_inf - 2.0 * t * beta_2_t / (1.0 - beta_2_t)

        for p, g, m, v, vhat in zip(params, grads, ms, vs, vhats):
            m_t = (self.beta_1 * m) + (1. - self.beta_1) * g
            v_t = (self.beta_2 * v) + (1. - self.beta_2) * K.square(g)

            m_corr_t = m_t / (1.0 - beta_1_t)
            if self.amsgrad:
                vhat_t = K.maximum(vhat, v_t)
                v_corr_t = K.sqrt(vhat_t / (1.0 - beta_2_t) + self.epsilon)
                self.updates.append(K.update(vhat, vhat_t))
            else:
                v_corr_t = K.sqrt(v_t / (1.0 - beta_2_t) + self.epsilon)

            r_t = K.sqrt((sma_t - 4.0) / (sma_inf - 4.0) *
                         (sma_t - 2.0) / (sma_inf - 2.0) *
                         sma_inf / sma_t)

            p_t = K.switch(sma_t >= 5, r_t * m_corr_t / v_corr_t, m_corr_t)

            if self.initial_weight_decay > 0:
                p_t += self.weight_decay * p

            p_t = p - lr * p_t

            self.updates.append(K.update(m, m_t))
            self.updates.append(K.update(v, v_t))
            new_p = p_t

            # Apply constraints.
            if getattr(p, 'constraint', None) is not None:
                new_p = p.constraint(new_p)

            self.updates.append(K.update(p, new_p))
        return self.updates

    def get_config(self):
        config = {
            'lr': float(K.get_value(self.lr)),
            'beta_1': float(K.get_value(self.beta_1)),
            'beta_2': float(K.get_value(self.beta_2)),
            'decay': float(K.get_value(self.decay)),
            'weight_decay': float(K.get_value(self.weight_decay)),
            'epsilon': self.epsilon,
            'amsgrad': self.amsgrad,
            'total_steps': float(K.get_value(self.total_steps)),
            'warmup_proportion': float(K.get_value(self.warmup_proportion)),
            'min_lr': float(K.get_value(self.min_lr)),
        }
        base_config = super(RAdam, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

# %%
def dice_coef(y_true, y_pred, smooth=1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_loss(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = y_true_f * y_pred_f
    score = (2. * K.sum(intersection) + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return 1. - score

def bce_dice_loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)

# %%
class DataGenerator(keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_IDs, df, target_df=None, mode='fit',
                 base_path='/content/competitions/understanding_cloud_organization',
                 batch_size=32, dim=(1400, 2100), n_channels=3, reshape=None,
                 augment=False, n_classes=4, random_state=2019, shuffle=True):
        self.dim = dim
        self.batch_size = batch_size
        self.df = df
        self.mode = mode
        self.base_path = base_path
        self.target_df = target_df
        self.list_IDs = list_IDs
        self.reshape = reshape
        self.n_channels = n_channels
        self.augment = augment
        self.n_classes = n_classes
        self.shuffle = shuffle
        self.random_state = random_state
        
        self.on_epoch_end()
        np.random.seed(self.random_state)

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        list_IDs_batch = [self.list_IDs[k] for k in indexes]
        
        X = self.__generate_X(list_IDs_batch)
        
        if self.mode == 'fit':
            y = self.__generate_y(list_IDs_batch)
            
            if self.augment:
                X, y = self.__augment_batch(X, y)
            
            return X, y
        
        elif self.mode == 'predict':
            return X

        else:
            raise AttributeError('The mode parameter should be set to "fit" or "predict".')
        
    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.seed(self.random_state)
            np.random.shuffle(self.indexes)
    
    def __generate_X(self, list_IDs_batch):
        'Generates data containing batch_size samples'
        # Initialization
        if self.reshape is None:
            X = np.empty((self.batch_size, *self.dim, self.n_channels))
        else:
            X = np.empty((self.batch_size, *self.reshape, self.n_channels))
        
        # Generate data
        for i, ID in enumerate(list_IDs_batch):
            im_name = self.df['ImageId'].iloc[ID]
            img_path = f"{self.base_path}/{im_name}"
            img = self.__load_rgb(img_path)
            
            if self.reshape is not None:
                img = np_resize(img, self.reshape)
            
            # Store samples
            X[i,] = img

        return X
    
    def __generate_y(self, list_IDs_batch):
        if self.reshape is None:
            y = np.empty((self.batch_size, *self.dim, self.n_classes), dtype=int)
        else:
            y = np.empty((self.batch_size, *self.reshape, self.n_classes), dtype=int)
        
        for i, ID in enumerate(list_IDs_batch):
            im_name = self.df['ImageId'].iloc[ID]
            image_df = self.target_df[self.target_df['ImageId'] == im_name]
            
            rles = image_df['EncodedPixels'].values
            
            if self.reshape is not None:
                masks = build_masks(rles, input_shape=self.dim, reshape=self.reshape)
            else:
                masks = build_masks(rles, input_shape=self.dim)
            
            y[i, ] = masks

        return y
    
    def __load_grayscale(self, img_path):
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        img = img.astype(np.float32) / 255.
        img = np.expand_dims(img, axis=-1)

        return img
    
    def __load_rgb(self, img_path):
        img = cv2.imread(img_path)
        #print(img)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = img.astype(np.float32) / 255.

        return img
    
    def __random_transform(self, img, masks):
        composition = albu.Compose([
            albu.HorizontalFlip(),
            albu.VerticalFlip(),
            albu.ShiftScaleRotate(rotate_limit=45, shift_limit=0.15, scale_limit=0.15)
        ])
        
        composed = composition(image=img, mask=masks)
        aug_img = composed['image']
        aug_masks = composed['mask']
        
        return aug_img, aug_masks
    
    def __augment_batch(self, img_batch, masks_batch):
        for i in range(img_batch.shape[0]):
            img_batch[i, ], masks_batch[i, ] = self.__random_transform(
                img_batch[i, ], masks_batch[i, ])
        
        return img_batch, masks_batch

# %%
def vanilla_unet(input_shape):
    """
    This is the old model. Best LB is ~0.5
    """
    inputs = Input(input_shape)

    c1 = Conv2D(8, (3, 3), activation='elu', padding='same') (inputs)
    c1 = Conv2D(8, (3, 3), activation='elu', padding='same') (c1)
    p1 = MaxPooling2D((2, 2), padding='same') (c1)

    c2 = Conv2D(16, (3, 3), activation='elu', padding='same') (p1)
    c2 = Conv2D(16, (3, 3), activation='elu', padding='same') (c2)
    p2 = MaxPooling2D((2, 2), padding='same') (c2)

    c3 = Conv2D(32, (3, 3), activation='elu', padding='same') (p2)
    c3 = Conv2D(32, (3, 3), activation='elu', padding='same') (c3)
    p3 = MaxPooling2D((2, 2), padding='same') (c3)

    c4 = Conv2D(64, (3, 3), activation='elu', padding='same') (p3)
    c4 = Conv2D(64, (3, 3), activation='elu', padding='same') (c4)
    p4 = MaxPooling2D((2, 2), padding='same') (c4)

    c5 = Conv2D(64, (3, 3), activation='elu', padding='same') (p4)
    c5 = Conv2D(64, (3, 3), activation='elu', padding='same') (c5)
    p5 = MaxPooling2D((2, 2), padding='same') (c5)

    c55 = Conv2D(128, (3, 3), activation='elu', padding='same') (p5)
    c55 = Conv2D(128, (3, 3), activation='elu', padding='same') (c55)

    u6 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c55)
    u6 = concatenate([u6, c5])
    c6 = Conv2D(64, (3, 3), activation='elu', padding='same') (u6)
    c6 = Conv2D(64, (3, 3), activation='elu', padding='same') (c6)

    u71 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c6)
    u71 = concatenate([u71, c4])
    c71 = Conv2D(32, (3, 3), activation='elu', padding='same') (u71)
    c61 = Conv2D(32, (3, 3), activation='elu', padding='same') (c71)

    u7 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c61)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(32, (3, 3), activation='elu', padding='same') (u7)
    c7 = Conv2D(32, (3, 3), activation='elu', padding='same') (c7)

    u8 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(16, (3, 3), activation='elu', padding='same') (u8)
    c8 = Conv2D(16, (3, 3), activation='elu', padding='same') (c8)

    u9 = Conv2DTranspose(8, (2, 2), strides=(2, 2), padding='same') (c8)
    u9 = concatenate([u9, c1], axis=3)
    c9 = Conv2D(8, (3, 3), activation='elu', padding='same') (u9)
    c9 = Conv2D(8, (3, 3), activation='elu', padding='same') (c9)

    outputs = Conv2D(4, (1, 1), activation='sigmoid') (c9)

    model = Model(inputs=[inputs], outputs=[outputs])
    
    return model

# %%
BATCH_SIZE = 16

train_idx, val_idx = train_test_split(
    mask_count_df.index, random_state=2019, test_size=0.2
)

train_generator = DataGenerator(
    train_idx, 
    df=mask_count_df,
    target_df=train_df,
    batch_size=BATCH_SIZE,
    reshape=(320, 480),
    augment=True,
    n_channels=3,
    n_classes=4
)

val_generator = DataGenerator(
    val_idx, 
    df=mask_count_df,
    target_df=train_df,
    batch_size=BATCH_SIZE, 
    reshape=(320, 480),
    augment=False,
    n_channels=3,
    n_classes=4
)

# %%
model = sm.Unet(
    'resnet34', 
    classes=4,
    input_shape=(320, 480,3),
    activation='sigmoid'
)
model.compile(optimizer=Nadam(lr=0.0002), loss=bce_dice_loss, metrics=[dice_coef])
model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Downloading data from https://github.com/qubvel/classification_models/releases/download/0.0.1/resnet34_imagenet_1000_no_top.h5
# 85524480/85521592 [==============================] - 1s 0us/step
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2239: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3657: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# data (InputLayer)               (None, 320, 480, 3)  0
# __________________________________________________________________________________________________
# bn_data (BatchNormalization)    (None, 320, 480, 3)  9           data[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 326, 486, 3)  0           bn_data[0][0]
# __________________________________________________________________________________________________
# conv0 (Conv2D)                  (None, 160, 240, 64) 9408        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn0 (BatchNormalization)        (None, 160, 240, 64) 256         conv0[0][0]
# __________________________________________________________________________________________________
# relu0 (Activation)              (None, 160, 240, 64) 0           bn0[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 162, 242, 64) 0           relu0[0][0]
# __________________________________________________________________________________________________
# pooling0 (MaxPooling2D)         (None, 80, 120, 64)  0           zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_bn1 (BatchNormaliz (None, 80, 120, 64)  256         pooling0[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_relu1 (Activation) (None, 80, 120, 64)  0           stage1_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 82, 122, 64)  0           stage1_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_conv1 (Conv2D)     (None, 80, 120, 64)  36864       zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_bn2 (BatchNormaliz (None, 80, 120, 64)  256         stage1_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_relu2 (Activation) (None, 80, 120, 64)  0           stage1_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 82, 122, 64)  0           stage1_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_conv2 (Conv2D)     (None, 80, 120, 64)  36864       zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_sc (Conv2D)        (None, 80, 120, 64)  4096        stage1_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 80, 120, 64)  0           stage1_unit1_conv2[0][0]
#                                                                  stage1_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_bn1 (BatchNormaliz (None, 80, 120, 64)  256         add_1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_relu1 (Activation) (None, 80, 120, 64)  0           stage1_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 82, 122, 64)  0           stage1_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_conv1 (Conv2D)     (None, 80, 120, 64)  36864       zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_bn2 (BatchNormaliz (None, 80, 120, 64)  256         stage1_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_relu2 (Activation) (None, 80, 120, 64)  0           stage1_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 82, 122, 64)  0           stage1_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_conv2 (Conv2D)     (None, 80, 120, 64)  36864       zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 80, 120, 64)  0           stage1_unit2_conv2[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_bn1 (BatchNormaliz (None, 80, 120, 64)  256         add_2[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_relu1 (Activation) (None, 80, 120, 64)  0           stage1_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_7 (ZeroPadding2D (None, 82, 122, 64)  0           stage1_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_conv1 (Conv2D)     (None, 80, 120, 64)  36864       zero_padding2d_7[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_bn2 (BatchNormaliz (None, 80, 120, 64)  256         stage1_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_relu2 (Activation) (None, 80, 120, 64)  0           stage1_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_8 (ZeroPadding2D (None, 82, 122, 64)  0           stage1_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_conv2 (Conv2D)     (None, 80, 120, 64)  36864       zero_padding2d_8[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 80, 120, 64)  0           stage1_unit3_conv2[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_bn1 (BatchNormaliz (None, 80, 120, 64)  256         add_3[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_relu1 (Activation) (None, 80, 120, 64)  0           stage2_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_9 (ZeroPadding2D (None, 82, 122, 64)  0           stage2_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_conv1 (Conv2D)     (None, 40, 60, 128)  73728       zero_padding2d_9[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_bn2 (BatchNormaliz (None, 40, 60, 128)  512         stage2_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_relu2 (Activation) (None, 40, 60, 128)  0           stage2_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_10 (ZeroPadding2 (None, 42, 62, 128)  0           stage2_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_conv2 (Conv2D)     (None, 40, 60, 128)  147456      zero_padding2d_10[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_sc (Conv2D)        (None, 40, 60, 128)  8192        stage2_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 40, 60, 128)  0           stage2_unit1_conv2[0][0]
#                                                                  stage2_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_bn1 (BatchNormaliz (None, 40, 60, 128)  512         add_4[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_relu1 (Activation) (None, 40, 60, 128)  0           stage2_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_11 (ZeroPadding2 (None, 42, 62, 128)  0           stage2_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_conv1 (Conv2D)     (None, 40, 60, 128)  147456      zero_padding2d_11[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_bn2 (BatchNormaliz (None, 40, 60, 128)  512         stage2_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_relu2 (Activation) (None, 40, 60, 128)  0           stage2_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_12 (ZeroPadding2 (None, 42, 62, 128)  0           stage2_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_conv2 (Conv2D)     (None, 40, 60, 128)  147456      zero_padding2d_12[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 40, 60, 128)  0           stage2_unit2_conv2[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_bn1 (BatchNormaliz (None, 40, 60, 128)  512         add_5[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_relu1 (Activation) (None, 40, 60, 128)  0           stage2_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_13 (ZeroPadding2 (None, 42, 62, 128)  0           stage2_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_conv1 (Conv2D)     (None, 40, 60, 128)  147456      zero_padding2d_13[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_bn2 (BatchNormaliz (None, 40, 60, 128)  512         stage2_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_relu2 (Activation) (None, 40, 60, 128)  0           stage2_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_14 (ZeroPadding2 (None, 42, 62, 128)  0           stage2_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_conv2 (Conv2D)     (None, 40, 60, 128)  147456      zero_padding2d_14[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 40, 60, 128)  0           stage2_unit3_conv2[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_bn1 (BatchNormaliz (None, 40, 60, 128)  512         add_6[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_relu1 (Activation) (None, 40, 60, 128)  0           stage2_unit4_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_15 (ZeroPadding2 (None, 42, 62, 128)  0           stage2_unit4_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_conv1 (Conv2D)     (None, 40, 60, 128)  147456      zero_padding2d_15[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_bn2 (BatchNormaliz (None, 40, 60, 128)  512         stage2_unit4_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_relu2 (Activation) (None, 40, 60, 128)  0           stage2_unit4_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_16 (ZeroPadding2 (None, 42, 62, 128)  0           stage2_unit4_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_conv2 (Conv2D)     (None, 40, 60, 128)  147456      zero_padding2d_16[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 40, 60, 128)  0           stage2_unit4_conv2[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_bn1 (BatchNormaliz (None, 40, 60, 128)  512         add_7[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_relu1 (Activation) (None, 40, 60, 128)  0           stage3_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_17 (ZeroPadding2 (None, 42, 62, 128)  0           stage3_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_conv1 (Conv2D)     (None, 20, 30, 256)  294912      zero_padding2d_17[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_bn2 (BatchNormaliz (None, 20, 30, 256)  1024        stage3_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_relu2 (Activation) (None, 20, 30, 256)  0           stage3_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_18 (ZeroPadding2 (None, 22, 32, 256)  0           stage3_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_conv2 (Conv2D)     (None, 20, 30, 256)  589824      zero_padding2d_18[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_sc (Conv2D)        (None, 20, 30, 256)  32768       stage3_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 20, 30, 256)  0           stage3_unit1_conv2[0][0]
#                                                                  stage3_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_bn1 (BatchNormaliz (None, 20, 30, 256)  1024        add_8[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_relu1 (Activation) (None, 20, 30, 256)  0           stage3_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_19 (ZeroPadding2 (None, 22, 32, 256)  0           stage3_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_conv1 (Conv2D)     (None, 20, 30, 256)  589824      zero_padding2d_19[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_bn2 (BatchNormaliz (None, 20, 30, 256)  1024        stage3_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_relu2 (Activation) (None, 20, 30, 256)  0           stage3_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_20 (ZeroPadding2 (None, 22, 32, 256)  0           stage3_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_conv2 (Conv2D)     (None, 20, 30, 256)  589824      zero_padding2d_20[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 20, 30, 256)  0           stage3_unit2_conv2[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_bn1 (BatchNormaliz (None, 20, 30, 256)  1024        add_9[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_relu1 (Activation) (None, 20, 30, 256)  0           stage3_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_21 (ZeroPadding2 (None, 22, 32, 256)  0           stage3_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_conv1 (Conv2D)     (None, 20, 30, 256)  589824      zero_padding2d_21[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_bn2 (BatchNormaliz (None, 20, 30, 256)  1024        stage3_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_relu2 (Activation) (None, 20, 30, 256)  0           stage3_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_22 (ZeroPadding2 (None, 22, 32, 256)  0           stage3_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_conv2 (Conv2D)     (None, 20, 30, 256)  589824      zero_padding2d_22[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 20, 30, 256)  0           stage3_unit3_conv2[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_bn1 (BatchNormaliz (None, 20, 30, 256)  1024        add_10[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_relu1 (Activation) (None, 20, 30, 256)  0           stage3_unit4_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_23 (ZeroPadding2 (None, 22, 32, 256)  0           stage3_unit4_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_conv1 (Conv2D)     (None, 20, 30, 256)  589824      zero_padding2d_23[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_bn2 (BatchNormaliz (None, 20, 30, 256)  1024        stage3_unit4_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_relu2 (Activation) (None, 20, 30, 256)  0           stage3_unit4_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_24 (ZeroPadding2 (None, 22, 32, 256)  0           stage3_unit4_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_conv2 (Conv2D)     (None, 20, 30, 256)  589824      zero_padding2d_24[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 20, 30, 256)  0           stage3_unit4_conv2[0][0]
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_bn1 (BatchNormaliz (None, 20, 30, 256)  1024        add_11[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_relu1 (Activation) (None, 20, 30, 256)  0           stage3_unit5_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_25 (ZeroPadding2 (None, 22, 32, 256)  0           stage3_unit5_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_conv1 (Conv2D)     (None, 20, 30, 256)  589824      zero_padding2d_25[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_bn2 (BatchNormaliz (None, 20, 30, 256)  1024        stage3_unit5_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_relu2 (Activation) (None, 20, 30, 256)  0           stage3_unit5_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_26 (ZeroPadding2 (None, 22, 32, 256)  0           stage3_unit5_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_conv2 (Conv2D)     (None, 20, 30, 256)  589824      zero_padding2d_26[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 20, 30, 256)  0           stage3_unit5_conv2[0][0]
#                                                                  add_11[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_bn1 (BatchNormaliz (None, 20, 30, 256)  1024        add_12[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_relu1 (Activation) (None, 20, 30, 256)  0           stage3_unit6_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_27 (ZeroPadding2 (None, 22, 32, 256)  0           stage3_unit6_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_conv1 (Conv2D)     (None, 20, 30, 256)  589824      zero_padding2d_27[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_bn2 (BatchNormaliz (None, 20, 30, 256)  1024        stage3_unit6_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_relu2 (Activation) (None, 20, 30, 256)  0           stage3_unit6_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_28 (ZeroPadding2 (None, 22, 32, 256)  0           stage3_unit6_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_conv2 (Conv2D)     (None, 20, 30, 256)  589824      zero_padding2d_28[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 20, 30, 256)  0           stage3_unit6_conv2[0][0]
#                                                                  add_12[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_bn1 (BatchNormaliz (None, 20, 30, 256)  1024        add_13[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_relu1 (Activation) (None, 20, 30, 256)  0           stage4_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_29 (ZeroPadding2 (None, 22, 32, 256)  0           stage4_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_conv1 (Conv2D)     (None, 10, 15, 512)  1179648     zero_padding2d_29[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_bn2 (BatchNormaliz (None, 10, 15, 512)  2048        stage4_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_relu2 (Activation) (None, 10, 15, 512)  0           stage4_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_30 (ZeroPadding2 (None, 12, 17, 512)  0           stage4_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_conv2 (Conv2D)     (None, 10, 15, 512)  2359296     zero_padding2d_30[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_sc (Conv2D)        (None, 10, 15, 512)  131072      stage4_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 10, 15, 512)  0           stage4_unit1_conv2[0][0]
#                                                                  stage4_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_bn1 (BatchNormaliz (None, 10, 15, 512)  2048        add_14[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_relu1 (Activation) (None, 10, 15, 512)  0           stage4_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_31 (ZeroPadding2 (None, 12, 17, 512)  0           stage4_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_conv1 (Conv2D)     (None, 10, 15, 512)  2359296     zero_padding2d_31[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_bn2 (BatchNormaliz (None, 10, 15, 512)  2048        stage4_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_relu2 (Activation) (None, 10, 15, 512)  0           stage4_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_32 (ZeroPadding2 (None, 12, 17, 512)  0           stage4_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_conv2 (Conv2D)     (None, 10, 15, 512)  2359296     zero_padding2d_32[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 10, 15, 512)  0           stage4_unit2_conv2[0][0]
#                                                                  add_14[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_bn1 (BatchNormaliz (None, 10, 15, 512)  2048        add_15[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_relu1 (Activation) (None, 10, 15, 512)  0           stage4_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_33 (ZeroPadding2 (None, 12, 17, 512)  0           stage4_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_conv1 (Conv2D)     (None, 10, 15, 512)  2359296     zero_padding2d_33[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_bn2 (BatchNormaliz (None, 10, 15, 512)  2048        stage4_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_relu2 (Activation) (None, 10, 15, 512)  0           stage4_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_34 (ZeroPadding2 (None, 12, 17, 512)  0           stage4_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_conv2 (Conv2D)     (None, 10, 15, 512)  2359296     zero_padding2d_34[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 10, 15, 512)  0           stage4_unit3_conv2[0][0]
#                                                                  add_15[0][0]
# __________________________________________________________________________________________________
# bn1 (BatchNormalization)        (None, 10, 15, 512)  2048        add_16[0][0]
# __________________________________________________________________________________________________
# relu1 (Activation)              (None, 10, 15, 512)  0           bn1[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_upsampling (UpSa (None, 20, 30, 512)  0           relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_concat (Concaten (None, 20, 30, 768)  0           decoder_stage0_upsampling[0][0]
#                                                                  stage4_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage0a_conv (Conv2D)   (None, 20, 30, 256)  1769472     decoder_stage0_concat[0][0]
# __________________________________________________________________________________________________
# decoder_stage0a_bn (BatchNormal (None, 20, 30, 256)  1024        decoder_stage0a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage0a_relu (Activatio (None, 20, 30, 256)  0           decoder_stage0a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage0b_conv (Conv2D)   (None, 20, 30, 256)  589824      decoder_stage0a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage0b_bn (BatchNormal (None, 20, 30, 256)  1024        decoder_stage0b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage0b_relu (Activatio (None, 20, 30, 256)  0           decoder_stage0b_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_upsampling (UpSa (None, 40, 60, 256)  0           decoder_stage0b_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_concat (Concaten (None, 40, 60, 384)  0           decoder_stage1_upsampling[0][0]
#                                                                  stage3_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage1a_conv (Conv2D)   (None, 40, 60, 128)  442368      decoder_stage1_concat[0][0]
# __________________________________________________________________________________________________
# decoder_stage1a_bn (BatchNormal (None, 40, 60, 128)  512         decoder_stage1a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage1a_relu (Activatio (None, 40, 60, 128)  0           decoder_stage1a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage1b_conv (Conv2D)   (None, 40, 60, 128)  147456      decoder_stage1a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage1b_bn (BatchNormal (None, 40, 60, 128)  512         decoder_stage1b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage1b_relu (Activatio (None, 40, 60, 128)  0           decoder_stage1b_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_upsampling (UpSa (None, 80, 120, 128) 0           decoder_stage1b_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_concat (Concaten (None, 80, 120, 192) 0           decoder_stage2_upsampling[0][0]
#                                                                  stage2_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage2a_conv (Conv2D)   (None, 80, 120, 64)  110592      decoder_stage2_concat[0][0]
# __________________________________________________________________________________________________
# decoder_stage2a_bn (BatchNormal (None, 80, 120, 64)  256         decoder_stage2a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage2a_relu (Activatio (None, 80, 120, 64)  0           decoder_stage2a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage2b_conv (Conv2D)   (None, 80, 120, 64)  36864       decoder_stage2a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage2b_bn (BatchNormal (None, 80, 120, 64)  256         decoder_stage2b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage2b_relu (Activatio (None, 80, 120, 64)  0           decoder_stage2b_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_upsampling (UpSa (None, 160, 240, 64) 0           decoder_stage2b_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_concat (Concaten (None, 160, 240, 128 0           decoder_stage3_upsampling[0][0]
#                                                                  relu0[0][0]
# __________________________________________________________________________________________________
# decoder_stage3a_conv (Conv2D)   (None, 160, 240, 32) 36864       decoder_stage3_concat[0][0]
# __________________________________________________________________________________________________
# decoder_stage3a_bn (BatchNormal (None, 160, 240, 32) 128         decoder_stage3a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage3a_relu (Activatio (None, 160, 240, 32) 0           decoder_stage3a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage3b_conv (Conv2D)   (None, 160, 240, 32) 9216        decoder_stage3a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage3b_bn (BatchNormal (None, 160, 240, 32) 128         decoder_stage3b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage3b_relu (Activatio (None, 160, 240, 32) 0           decoder_stage3b_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_upsampling (UpSa (None, 320, 480, 32) 0           decoder_stage3b_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage4a_conv (Conv2D)   (None, 320, 480, 16) 4608        decoder_stage4_upsampling[0][0]
# __________________________________________________________________________________________________
# decoder_stage4a_bn (BatchNormal (None, 320, 480, 16) 64          decoder_stage4a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage4a_relu (Activatio (None, 320, 480, 16) 0           decoder_stage4a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage4b_conv (Conv2D)   (None, 320, 480, 16) 2304        decoder_stage4a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage4b_bn (BatchNormal (None, 320, 480, 16) 64          decoder_stage4b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage4b_relu (Activatio (None, 320, 480, 16) 0           decoder_stage4b_bn[0][0]
# __________________________________________________________________________________________________
# final_conv (Conv2D)             (None, 320, 480, 4)  580         decoder_stage4b_relu[0][0]
# __________________________________________________________________________________________________
# sigmoid (Activation)            (None,
# 2c799cb.jpg                                    2019-08-07 23:09:02       729557
# be7908a.jpg                                    2019-08-07 23:24:46       658235
# 60de9d5.jpg                                    2019-08-07 23:14:48       691422
# f8c81b2.jpg                                    2019-08-07 23:31:06       716828
# a21d2e5.jpg                                    2019-08-07 23:21:50       756056
# 22eca9b.jpg                                    2019-08-07 23:08:00       625365
# a9f744f.jpg                                    2019-08-07 23:22:42       656709
# a15f8e7.jpg                                    2019-08-07 23:21:44       588661
# 8d5f7a9.jpg                                    2019-08-07 23:19:42       568935
# af8df0d.jpg                                    2019-08-07 23:23:14       660642
# 9cbf068.jpg                                    2019-08-07 23:21:18       514783
# 4aeabae.jpg                                    2019-08-07 23:12:18       735985
# 34009a3.jpg                                    2019-08-07 23:09:52       697573
# 425d22b.jpg                                    2019-08-07 23:11:28       541823
# 35c9c03.jpg                                    2019-08-07 23:10:06       612595
# da1dd3f.jpg                                    2019-08-07 23:27:44       847506
# 24c16bb.jpg                                    2019-08-07 23:08:12       554031
# 7a00b78.jpg                                    2019-08-07 23:17:36       694889
# c329bfc.jpg                                    2019-08-07 23:25:14       699080
# 30fc15d.jpg                                    2019-08-07 23:09:32       714206
# f6cd5e7.jpg                                    2019-08-07 23:30:54       562693
# 6c6675c.jpg                                    2019-08-07 23:16:04       683126
# 1120e13.jpg                                    2019-08-07 23:05:50       823189
# 2f1f439.jpg                                    2019-08-07 23:09:18       633416
# dd1744a.jpg                                    2019-08-07 23:28:02       649683
# d741260.jpg                                    2019-08-07 23:27:24       657825
# dc37348.jpg                                    2019-08-07 23:27:56       622380
# 3a988a0.jpg                                    2019-08-07 23:10:38       741562
# c32bfd6.jpg                                    2019-08-07 23:25:14       782324
# Extracting all the files now...
# Done!

# %%
import tensorflow as tf
gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=0.5)
config = tf.ConfigProto(gpu_options=gpu_options)
config.gpu_options.allow_growth = True
session = tf.Session(config=config)

# %%
checkpoint = ModelCheckpoint('model.h5', save_best_only=True)

history  = model.fit_generator(
    train_generator,
    validation_data=val_generator,
    callbacks=[checkpoint],
    epochs=15
)
# Out:
# Epoch 1/15
# 277/277 [==============================] - 824s 3s/step - loss: 1.0515 - dice_coef: 0.3741 - val_loss: 1.0045 - val_dice_coef: 0.4237
# Epoch 2/15
# 277/277 [==============================] - 776s 3s/step - loss: 0.8608 - dice_coef: 0.4643 - val_loss: 0.8509 - val_dice_coef: 0.5050
# Epoch 3/15
# 277/277 [==============================] - 790s 3s/step - loss: 0.8301 - dice_coef: 0.4912 - val_loss: 0.8147 - val_dice_coef: 0.5053
# Epoch 4/15
# 277/277 [==============================] - 819s 3s/step - loss: 0.8177 - dice_coef: 0.5013 - val_loss: 0.7904 - val_dice_coef: 0.5230
# Epoch 5/15
# 277/277 [==============================] - 835s 3s/step - loss: 0.8075 - dice_coef: 0.5089 - val_loss: 0.7697 - val_dice_coef: 0.5435
# Epoch 6/15
# 277/277 [==============================] - 804s 3s/step - loss: 0.7956 - dice_coef: 0.5169 - val_loss: 0.8125 - val_dice_coef: 0.5221
# Epoch 7/15
# 277/277 [==============================] - 803s 3s/step - loss: 0.7901 - dice_coef: 0.5215 - val_loss: 0.7911 - val_dice_coef: 0.5341
# Epoch 8/15
# 277/277 [==============================] - 800s 3s/step - loss: 0.7803 - dice_coef: 0.5272 - val_loss: 0.7945 - val_dice_coef: 0.5380
# Epoch 9/15
# 277/277 [==============================] - 796s 3s/step - loss: 0.7760 - dice_coef: 0.5305 - val_loss: 0.7624 - val_dice_coef: 0.5468
# Epoch 10/15
# 277/277 [==============================] - 795s 3s/step - loss: 0.7654 - dice_coef: 0.5378 - val_loss: 0.7784 - val_dice_coef: 0.5450
# Epoch 11/15
# 277/277 [==============================] - 803s 3s/step - loss: 0.7593 - dice_coef: 0.5421 - val_loss: 0.7807 - val_dice_coef: 0.5335
# Epoch 12/15
# 277/277 [==============================] - 795s 3s/step - loss: 0.7540 - dice_coef: 0.5448 - val_loss: 0.8226 - val_dice_coef: 0.5058
# Epoch 13/15
# 277/277 [==============================] - 808s 3s/step - loss: 0.7508 - dice_coef: 0.5480 - val_loss: 0.8296 - val_dice_coef: 0.5274
# Epoch 14/15
# 277/277 [==============================] - 778s 3s/step - loss: 0.7424 - dice_coef: 0.5525 - val_loss: 0.7624 - val_dice_coef: 0.5577
# Epoch 15/15
# 277/277 [==============================] - 802s 3s/step - loss: 0.7327 - dice_coef: 0.5597 - val_loss: 0.8680 - val_dice_coef: 0.4999

# %% [markdown]
# ## Evaluation

# %%
with open('history.json', 'w') as f:
    json.dump(history.history, f)

history_df = pd.DataFrame(history.history)
history_df[['loss', 'val_loss']].plot()
history_df[['dice_coef', 'val_dice_coef']].plot()

# %%
history_df
# Out:
#     val_loss  val_dice_coef      loss  dice_coef
# 0   1.004540       0.423676  1.051469   0.374100
# 1   0.850882       0.504979  0.860756   0.464289
# 2   0.814729       0.505337  0.830058   0.491178
# 3   0.790413       0.523033  0.817719   0.501272
# 4   0.769742       0.543466  0.807469   0.508903
# 5   0.812490       0.522063  0.795615   0.516880
# 6   0.791132       0.534089  0.790062   0.521522
# 7   0.794514       0.537990  0.780251   0.527169
# 8   0.762369       0.546815  0.776006   0.530521
# 9   0.778424       0.545007  0.765400   0.537799
# 10  0.780712       0.533462  0.759331   0.542085
# 11  0.822618       0.505754  0.753965   0.544752
# 12  0.829608       0.527390  0.750771   0.548033
# 13  0.762439       0.557702  0.742358   0.552510
# 14  0.868018       0.499879  0.732658   0.559678

# %%
print(history_df[['loss','val_loss']])
# Out:
#         loss  val_loss
# 0   1.051469  1.004540
# 1   0.860756  0.850882
# 2   0.830058  0.814729
# 3   0.817719  0.790413
# 4   0.807469  0.769742
# 5   0.795615  0.812490
# 6   0.790062  0.791132
# 7   0.780251  0.794514
# 8   0.776006  0.762369
# 9   0.765400  0.778424
# 10  0.759331  0.780712
# 11  0.753965  0.822618
# 12  0.750771  0.829608
# 13  0.742358  0.762439
# 14  0.732658  0.868018
